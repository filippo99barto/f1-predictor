# %%
import sys; sys.path.insert(0, "..")  # or absolute path to project root
from src.ingestion.silver_pipeline import SilverPipeline
from src.ingestion.gold_pipeline import GoldPipeline
from src.storage.local_storage_backend import LocalStorageBackend
from src.config.paths import LOCAL_DATA_DIR

storage = LocalStorageBackend(LOCAL_DATA_DIR)

silver_pipeline = SilverPipeline(storage)
silver_pipeline.build_silver_data()

gold_pipeline = GoldPipeline(storage)
gold_pipeline.build_gold_data()
# Out:
#       season  round                   raceName  \
# 931     2022      1         Bahrain Grand Prix
# 952     2022      2   Saudi Arabian Grand Prix
# 968     2022      3      Australian Grand Prix
# 989     2022      4  Emilia Romagna Grand Prix
# 1007    2022      5           Miami Grand Prix
# ...      ...    ...                        ...
# 833     2024     20     Mexico City Grand Prix
# 853     2024     21       São Paulo Grand Prix
# 871     2024     22       Las Vegas Grand Prix
# 886     2024     23           Qatar Grand Prix
# 911     2024     24       Abu Dhabi Grand Prix
#
#                          circuitName     locality       country  position  \
# 931    Bahrain International Circuit       Sakhir       Bahrain        13
# 952          Jeddah Corniche Circuit       Jeddah  Saudi Arabia        14
# 968   Albert Park Grand Prix Circuit    Melbourne     Australia        10
# 989    Autodromo Enzo e Dino Ferrari        Imola         Italy        11
# 1007   Miami International Autodrome        Miami           USA         9
# ...                              ...          ...           ...       ...
# 833     Autódromo Hermanos Rodríguez  Mexico City        Mexico        15
# 853       Autódromo José Carlos Pace    São Paulo        Brazil        15
# 871   Las Vegas Strip Street Circuit    Las Vegas           USA        13
# 886     Losail International Circuit       Lusail         Qatar         8
# 911               Yas Marina Circuit    Abu Dhabi           UAE        13
#
#       points  grid            status driverId constructorId  \
# 931      0.0    14          Finished    albon      williams
# 952      0.0    16  Collision damage    albon      williams
# 968      1.0    20          Finished    albon      williams
# 989      0.0    18            +1 Lap    albon      williams
# 1007     2.0    18          Finished    albon      williams
# ...      ...   ...               ...      ...           ...
# 833      0.0    19            Lapped     zhou        sauber
# 853      0.0    19          Finished     zhou        sauber
# 871      0.0    13          Finished     zhou        sauber
# 886      4.0    12          Finished     zhou        sauber
# 911      0.0    15            Lapped     zhou        sauber
#
#            race_datetime  driver_last_race_position  \
# 931  2022-03-20 15:00:00                        NaN
# 952  2022-03-27 17:00:00                       13.0
# 968  2022-04-10 05:00:00                       14.0
# 989  2022-04-24 13:00:00                       10.0
# 1007 2022-05-08 19:30:00                       11.0
# ...                  ...                        ...
# 833  2024-10-27 20:00:00                       19.0
# 853  2024-11-03 17:00:00                       15.0
# 871  2024-11-23 06:00:00                       15.0
# 886  2024-12-01 16:00:00                       13.0
# 911  2024-12-08 13:00:00                        8.0
#
#       driver_median_position_last_3_races
# 931                                   NaN
# 952                                  13.0
# 968                                  13.5
# 989                                  13.0
# 1007                                 11.0
# ...                                   ...
# 833                                  15.0
# 853                                  15.0
# 871                                  15.0
# 886                                  15.0
# 911                                  13.0
#
# [1359 rows x 15 columns]
