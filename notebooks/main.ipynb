# %%
import sys; sys.path.insert(0, "..")  # or absolute path to project root
from src.ingestion.silver_pipeline import SilverPipeline
from src.storage.local_storage_backend import LocalStorageBackend
from src.config.paths import LOCAL_DATA_DIR

storage = LocalStorageBackend(LOCAL_DATA_DIR)

silver_pipeline = SilverPipeline(storage)

silver_pipeline.build_silver_data()
# Out:
#       season  round              raceName            Circuit.circuitName  \
# 0       2023      1    Bahrain Grand Prix  Bahrain International Circuit
# 1       2023      1    Bahrain Grand Prix  Bahrain International Circuit
# 2       2023      1    Bahrain Grand Prix  Bahrain International Circuit
# 3       2023      1    Bahrain Grand Prix  Bahrain International Circuit
# 4       2023      1    Bahrain Grand Prix  Bahrain International Circuit
# ...      ...    ...                   ...                            ...
# 1354    2022     22  Abu Dhabi Grand Prix             Yas Marina Circuit
# 1355    2022     22  Abu Dhabi Grand Prix             Yas Marina Circuit
# 1356    2022     22  Abu Dhabi Grand Prix             Yas Marina Circuit
# 1357    2022     22  Abu Dhabi Grand Prix             Yas Marina Circuit
# 1358    2022     22  Abu Dhabi Grand Prix             Yas Marina Circuit
#
#      Circuit.Location.locality Circuit.Location.country       date       time  \
# 0                       Sakhir                  Bahrain 2023-03-05  15:00:00Z
# 1                       Sakhir                  Bahrain 2023-03-05  15:00:00Z
# 2                       Sakhir                  Bahrain 2023-03-05  15:00:00Z
# 3                       Sakhir                  Bahrain 2023-03-05  15:00:00Z
# 4                       Sakhir                  Bahrain 2023-03-05  15:00:00Z
# ...                        ...                      ...        ...        ...
# 1354                 Abu Dhabi                      UAE 2022-11-20  13:00:00Z
# 1355                 Abu Dhabi                      UAE 2022-11-20  13:00:00Z
# 1356                 Abu Dhabi                      UAE 2022-11-20  13:00:00Z
# 1357                 Abu Dhabi                      UAE 2022-11-20  13:00:00Z
# 1358                 Abu Dhabi                      UAE 2022-11-20  13:00:00Z
#
#       position  points  grid            status  Driver.driverId  \
# 0            1      25     1          Finished   max_verstappen
# 1            2      18     2          Finished            perez
# 2            3      15     5          Finished           alonso
# 3            4      12     4          Finished            sainz
# 4            5      10     7          Finished         hamilton
# ...        ...     ...   ...               ...              ...
# 1354        16       0    12            +1 Lap  mick_schumacher
# 1355        17       0    16            +1 Lap  kevin_magnussen
# 1356        18       0     5        Hydraulics         hamilton
# 1357        19       0    20  Collision damage           latifi
# 1358        20       0    10        Water leak           alonso
#
#      Constructor.constructorId
# 0                     red_bull
# 1                     red_bull
# 2                 aston_martin
# 3                      ferrari
# 4                     mercedes
# ...                        ...
# 1354                      haas
# 1355                      haas
# 1356                  mercedes
# 1357                  williams
# 1358                    alpine
#
# [1359 rows x 14 columns]
