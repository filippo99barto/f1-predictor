# %% [markdown]
# # F1 Prediction Assistant
#
# Ask natural-language questions about upcoming race predictions. The LLM calls your trained quali → race cascade models via tools — it does not guess results.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from f1_ml.models.race.predict import predict_next_race

result = predict_next_race()
print(f"{result.race_name} ({result.season} R{result.round}) @ {result.circuit_id}")
print(f"Predicted winner: {result.winner}")
print(f"Predicted podium: {result.podium}")
result.predictions.head(10)
# Out:
# Dutch Grand Prix (2026 R12) @ zandvoort
# Predicted winner: antonelli
# Predicted podium: ['antonelli', 'leclerc', 'max_verstappen']
#          driverId constructorId  predicted_qualifying_position  \
# 0       antonelli      mercedes                       3.883641
# 1         leclerc       ferrari                       4.048938
# 2  max_verstappen      red_bull                       4.568575
# 3        hamilton       ferrari                       3.865837
# 4          norris       mclaren                       4.437527
# 5         russell      mercedes                       3.404212
# 6         piastri       mclaren                       5.851856
# 7          hadjar      red_bull                       5.920810
# 8          lawson            rb                      11.537097
# 9           gasly        alpine                      11.760454
#
#    predicted_race_position
# 0                 2.485363
# 1                 2.960469
# 2                 3.016127
# 3                 3.114772
# 4                 3.338614
# 5                 3.508434
# 6                 4.624793
# 7                 5.488395
# 8                10.183223
# 9                11.280164

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from f1_agent.client import ask

print(ask("Who will win next race?"))
print(ask("What will the podium be at the next Grand Prix?"))
print(ask("Predict the top 10 for Belgium 2026"))
# Out:
# Based on my predictive models for the upcoming Dutch Grand Prix, here are the top three projected finishers:
#
# 1.  **Winner:** Antonelli (Mercedes)
# 2.  **2nd Place:** Leclerc (Ferrari)
# 3.  **3rd Place:** Max Verstappen (Red Bull)
#
# **Please note:** These are model estimates based on available data and are not certainties. Formula 1 is highly unpredictable, and actual race results may vary.
# The model's predicted podium for the upcoming Dutch Grand Prix is:
#
# 1.  **Antonelli** (Mercedes)
# 2.  **Leclerc** (Ferrari)
# 3.  **Max Verstappen** (Red Bull)
#
# Please keep in mind that these predictions are generated by machine learning models based on available data and are estimates, not certainties. Anything can happen once the cars hit the track!
# I apologize, but I am unable to provide a prediction specifically for the 2026 Belgian Grand Prix at this time, as my data model is currently focusing on upcoming events in the 2026 season.
#
# The current available prediction data is for the **2026 Dutch Grand Prix (Round 12)**. Here is the predicted top 10 for that race:
#
# | Position | Driver |
# | :--- | :--- |
# | 1 | Antonelli |
# | 2 | Leclerc |
# | 3 | Max Verstappen |
# | 4 | Hamilton |
# | 5 | Norris |
# | 6 | Russell |
# | 7 | Piastri |
# | 8 | Hadjar |
# | 9 | Lawson |
# | 10 | Gasly |
#
# ***Please note:** These predictions are generated by machine learning models and are estimates, not guaranteed outcomes. Actual race results can be influenced by many unpredictable factors.*
