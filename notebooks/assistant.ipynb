# %% [markdown]
# # F1 Prediction Assistant
#
# Ask natural-language questions about upcoming race predictions. The LLM calls your trained quali → race cascade models via tools — it does not guess results.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from f1_ml.models.cascade.predict import predict_next_race

result = predict_next_race(mode="production")
print(f"{result.race_name} ({result.season} R{result.round}) @ {result.circuit_id}")
print(f"Predicted winner: {result.winner}")
print(f"Predicted podium: {result.podium}")
result.predictions.head(10)
# Out:
# Dutch Grand Prix (2026 R12) @ zandvoort
# Predicted winner: antonelli
# Predicted podium: ['antonelli', 'hamilton', 'leclerc']
#          driverId constructorId  predicted_qualifying_position  \
# 0       antonelli      mercedes                       3.883641
# 1        hamilton       ferrari                       3.865837
# 2         leclerc       ferrari                       4.048938
# 3  max_verstappen      red_bull                       4.568575
# 4         russell      mercedes                       3.404212
# 5          norris       mclaren                       4.437527
# 6         piastri       mclaren                       5.851856
# 7          hadjar      red_bull                       5.920810
# 8          lawson            rb                      11.537097
# 9           gasly        alpine                      11.760454
#
#    predicted_race_position
# 0                 2.635363
# 1                 2.958055
# 2                 3.024111
# 3                 3.063197
# 4                 3.397164
# 5                 3.472747
# 6                 4.888073
# 7                 5.292148
# 8                10.292572
# 9                10.913204

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from f1_agent.client import ask

print(ask("Who will win next race?"))
print(ask("What will the podium be at the next Grand Prix?"))
print(ask("Predict the top 10 for Belgium 2026"))
# Out:
# For the upcoming Dutch Grand Prix, my machine learning models predict the following podium:
#
# 1. **Winner:** Antonelli (Mercedes)
# 2. **Second Place:** Hamilton (Ferrari)
# 3. **Third Place:** Leclerc (Ferrari)
#
# Please keep in mind that these are model estimates based on available data and not certainties; the actual race results can be influenced by many unpredictable variables.
# For the upcoming Dutch Grand Prix, my machine learning model predicts the following podium finish:
#
# 1.  **Andrea Kimi Antonelli** (Mercedes)
# 2.  **Lewis Hamilton** (Ferrari)
# 3.  **Charles Leclerc** (Ferrari)
#
# Please keep in mind that these are model estimates based on current data and performance trends, not certainties. The actual race results can be influenced by many variables such as weather, strategy, and on-track incidents.
# I apologize for the confusion; my current data model is configured for the 2026 season based on the upcoming Dutch Grand Prix. I do not have specific projections for the Belgian Grand Prix in 2026 at this time.
#
# Please note that these predictions are generated by machine learning models and are intended as estimates, not as definitive outcomes. Performance in Formula 1 can change rapidly due to car development, driver form, and race-day conditions.
