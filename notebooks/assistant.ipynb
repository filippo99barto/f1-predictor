# %% [markdown]
# # F1 Prediction Assistant
#
# Ask natural-language questions about upcoming race predictions. The LLM calls your trained quali → race cascade models via tools — it does not guess results.

# %%
import sys; sys.path.insert(0, "..")
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from src.models.cascade.predict import predict_next_race

result = predict_next_race(mode="production")
print(f"{result.race_name} ({result.season} R{result.round}) @ {result.circuit_id}")
print(f"Predicted winner: {result.winner}")
print(f"Predicted podium: {result.podium}")
result.predictions.head(10)
# Out:
# Belgian Grand Prix (2026 R10) @ spa
# Predicted winner: russell
# Predicted podium: ['russell', 'hamilton', 'antonelli']
#          driverId constructorId  predicted_qualifying_position  \
# 0         russell      mercedes                       2.882452
# 1        hamilton       ferrari                       4.013860
# 2       antonelli      mercedes                       3.302126
# 3         leclerc       ferrari                       3.930667
# 4  max_verstappen      red_bull                       4.171168
# 5          norris       mclaren                       5.301339
# 6         piastri       mclaren                       6.839957
# 7          hadjar      red_bull                       5.516552
# 8          lawson            rb                      11.160221
# 9           gasly        alpine                      11.886336
#
#    predicted_starting_position  predicted_race_position
# 0                            3                 2.929750
# 1                            4                 3.302904
# 2                            3                 3.303020
# 3                            4                 3.332525
# 4                            4                 4.229928
# 5                            5                 4.697795
# 6                            7                 5.777948
# 7                            6                 6.018796
# 8                           11                 9.662848
# 9                           12                10.264422

# %%
import sys; sys.path.insert(0, "..")
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from src.assistant.client import ask

print(ask("Who will win next race?"))
print(ask("What will the podium be at the next Grand Prix?"))
print(ask("Predict the top 10 for Belgium 2026"))
# Out:
# Based on my machine learning models, here are the top 3 predictions for the upcoming **Belgian Grand Prix**:
#
# 1.  **George Russell** (Winner)
# 2.  **Lewis Hamilton**
# 3.  **Andrea Kimi Antonelli**
#
# *Please note: These are model-based estimates and not certainties. Formula 1 is highly unpredictable, and actual race results may vary.*
# For the upcoming Belgian Grand Prix, my machine learning model predicts the following podium finish:
#
# 1.  **George Russell** (Winner)
# 2.  **Lewis Hamilton**
# 3.  **Kimi Antonelli**
#
# ***
#
# *Please note: These results are model estimates based on current data and performance trends, not certainties. Race outcomes are subject to many unpredictable variables.*
# Here is the model-predicted top 10 for the 2026 Belgian Grand Prix at Spa-Francorchamps:
#
# | Position | Driver | Constructor |
# | :--- | :--- | :--- |
# | 1 | George Russell | Mercedes |
# | 2 | Lewis Hamilton | Ferrari |
# | 3 | Andrea Kimi Antonelli | Mercedes |
# | 4 | Charles Leclerc | Ferrari |
# | 5 | Max Verstappen | Red Bull |
# | 6 | Lando Norris | McLaren |
# | 7 | Oscar Piastri | McLaren |
# | 8 | Isack Hadjar | Red Bull |
# | 9 | Liam Lawson | RB |
# | 10 | Pierre Gasly | Alpine |
#
# ***Disclaimer:** Please note that these predictions are generated by machine learning models based on available data and trends. They are estimates and not certainties, as actual race outcomes are subject to many unpredictable factors.*
