# %% [markdown]
# # F1 Prediction Assistant
#
# Ask natural-language questions about upcoming race predictions. The LLM calls your trained quali → race cascade models via tools — it does not guess results.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from f1_agent.client import ask

print(ask("Who will win next race?"))
print(ask("Why that driver?"))
print(ask("Who will get pole?"))
# Out:
# Based on my machine learning model's predictions for the upcoming Dutch Grand Prix, here are the expected top performers. Please note that these are model estimates and not certainties.
#
# ### Predicted Podium
# 1.  **Antonelli** (Mercedes)
# 2.  **Leclerc** (Ferrari)
# 3.  **Max Verstappen** (Red Bull)
#
# ### Full Predicted Classification
# | Position | Driver | Constructor |
# | :--- | :--- | :--- |
# | 1 | Antonelli | Mercedes |
# | 2 | Leclerc | Ferrari |
# | 3 | Max Verstappen | Red Bull |
# | 4 | Hamilton | Ferrari |
# | 5 | Norris | McLaren |
# | 6 | Russell | Mercedes |
# | 7 | Piastri | McLaren |
# | 8 | Hadjar | Red Bull |
# | 9 | Lawson | RB |
# | 10 | Gasly | Alpine |
# | 11 | Hulkenberg | Audi |
# | 12 | Arvid Lindblad | RB |
# | 13 | Colapinto | Alpine |
# | 14 | Sainz | Williams |
# | 15 | Bortoleto | Audi |
# | 16 | Bearman | Haas |
# | 17 | Ocon | Haas |
# | 18 | Alonso | Aston Martin |
# | 19 | Perez | Cadillac |
# | 20 | Albon | Williams |
# | 21 | Stroll | Aston Martin |
# | 22 | Bottas | Cadillac |
#
# ### Why these predictions?
# The model generates these results by analyzing several key performance indicators for each driver and constructor. For example:
# *   **Antonelli** is predicted to win primarily due to his strong form in the most recent races, where he achieved a median finishing position of 3rd, and his high qualifying potential (predicted around 3.8).
# *   **Leclerc** holds a strong position because Ferrari has maintained a competitive median constructor position (3rd over the last three races).
# *   **Max Verstappen** remains a podium contender largely due to his excellent historical performance at this circuit, with a career median position of 1.5 at Zandvoort.
#
# These inputs, combined with current season trends and recent qualifying data, determine the projected finishing order for the full field.
# To provide a specific explanation, could you please clarify which driver you are asking about?
#
# Each driver's predicted finish is calculated by our model using a specific set of inputs (features) that compare their current form, team performance, and historical track record. Once you let me know which driver interests you, I can break down the exact data points the model used to reach that conclusion.
# My machine learning model predicts that **Russell** will take pole position for the Dutch Grand Prix.
#
# Please keep in mind that these are model estimates, not certainties.
#
# ### Predicted Grid (Top 10)
# 1. **Russell** (Mercedes)
# 2. **Hamilton** (Ferrari)
# 3. **Antonelli** (Mercedes)
# 4. **Leclerc** (Ferrari)
# 5. **Norris** (McLaren)
# 6. **Max Verstappen** (Red Bull)
# 7. **Piastri** (McLaren)
# 8. **Hadjar** (Red Bull)
# 9. **Arvid Lindblad** (RB)
# 10. **Lawson** (RB)
#
# ### Why Russell?
# Russell's predicted pole position is driven by his strong qualifying metrics:
# *   **Consistency:** He has maintained an excellent qualifying median for the season (2nd).
# *   **Team Performance:** Mercedes has a strong constructor qualifying median (2.5), which provides a solid baseline for his performance.
# *   **Circuit History:** He has a solid historical qualifying median of 4.5 at Zandvoort, indicating he performs well at this specific venue.
#
# Would you like the full grid listing or details on another driver?
